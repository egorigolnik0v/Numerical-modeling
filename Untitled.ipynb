# %%
import numpy as np
import matplotlib.pyplot as plt
import math

w1  = []
A1 = []
w1 , A1 = np.loadtxt("/home/egor/Desktop/C++_programming/Вычислительные методы/Неделя_13/АЧХ1.txt", unpack = True, skiprows = 1)
w1 = np.array(w1)
plt.scatter(w1, A1, c= "r")
w1_2 = np.linspace(0.3, 1.5, num=500)
plt.plot(w1_2 , 2*np.array(1/((1-w1_2*w1_2)**2+0.01)**0.5))

"""
w2  = []
A2 = []
w2 , A2 = np.loadtxt("/home/egor/Desktop/C++_programming/Вычислительные методы/Неделя_13/АЧХ2.txt", unpack = True, skiprows = 1)
w2 = np.array(w2)
plt.scatter(w2, A2, c= "r")
w2_2 = np.linspace(0.3, 1.5, num=500)
plt.plot(w2_2 , 2*np.array(1/((1-w2_2*w2_2)**2+0.03*0.03)**0.5))

""" 

w3  = []
A3 = []
w3 , A3 = np.loadtxt("/home/egor/Desktop/C++_programming/Вычислительные методы/Неделя_13/АЧХ3.txt", unpack = True, skiprows = 1)
w3 = np.array(w3)
plt.scatter(w3, A3, c= "r")
w3_2 = np.linspace(0.3, 1.5, num=500)
plt.plot(w2_2 , 1*np.array(1/((1-w2_2*w2_2)**2+0.1*0.1)**0.5))

plt.show()

# %%
""" Метод Хойна """
t = []
x = []
v = []
E_K = []
E_P = []
E = []
t, x, v, E_K, E_P, E = np.loadtxt("/home/egor/Desktop/C++_programming/Вычислительные методы/Неделя_13/Data.txt", unpack = True)
A = x[380000:]
print(A[np. argmax(A)])

plt.scatter(t, x, s=2, c='r')
plt.xlabel('Time (секунды)')
plt.ylabel('x (метры)')
plt.title('X(t)')
phi = -1.57
"""plt.plot(t, 0.25*((np.ones(199553) - np.exp(-0.05*t))*np.sin(1.2*t+phi)))"""
plt.show()
# Out:
# 5.72984

# %%
plt.scatter(t, v, s=2, c='r')
plt.xlabel('Time (секунды)')
plt.ylabel('v (метр/секунды)')
plt.title('V(t)')
plt.show()

# %%
plt.scatter(x, v, s=2, c='r')
plt.xlabel('x (метры)')
plt.ylabel('v (метры/секунды)')
plt.title('V(X)')
plt.show()

# %%
plt.scatter(t, E_K, s=2, c = 'r')
plt.xlabel('Time (секунды)')
plt.ylabel('Kinetic Energy (Джоули)')
plt.title('E_K(t)')
plt.show()

# %%
plt.scatter(t, E_P, s=2, c = 'r')
plt.xlabel('Time (секунды)')
plt.ylabel('Potential Energy (Джоули)')
plt.title('E_P(t)')
plt.show()

# %%
plt.scatter(t, E, s=2, c = 'r')
plt.xlabel('Time (секунды)')
plt.ylabel('Energy (Джоули)')
plt.title('E(t)')
plt.show()
